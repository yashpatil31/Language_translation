# %%
# !pip install deep-translator
# Out:
# Collecting deep-translator
#   Downloading deep_translator-1.11.4-py3-none-any.whl (42 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.3/42.3 kB 1.2 MB/s eta 0:00:00
# Requirement already satisfied: beautifulsoup4<5.0.0,>=4.9.1 in /usr/local/lib/python3.10/dist-packages (from deep-translator) (4.11.2)
# Requirement already satisfied: requests<3.0.0,>=2.23.0 in /usr/local/lib/python3.10/dist-packages (from deep-translator) (2.31.0)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4<5.0.0,>=4.9.1->deep-translator) (2.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.23.0->deep-translator) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.23.0->deep-translator) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.23.0->deep-translator) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.23.0->deep-translator) (2023.11.17)
# Installing collected packages: deep-translator
# Successfully installed deep-translator-1.11.4

# %%
# using GoogleTranslator a free module that is based on google translate and is provided as a part of deep_translator
import time
import pandas as pd
from deep_translator import GoogleTranslator

# %%
df = pd.read_excel("Order_Export.xls", engine="xlrd")
df.head()
# Out:
#            订单编号  买家公司名        买家会员名          卖家公司名   卖家会员名  货品总价(元)  运费(元)  \
# 0  3.704877e+18    NaN  tb582836650  台州市路桥乐缇电子商务商行    乐缇贸易     75.0   10.0
# 1           NaN    NaN          NaN            NaN     NaN      NaN    NaN
# 2  3.704473e+18    NaN  tb582836650    深圳市龙华区永豪皮具厂  新永豪皮具厂     78.0    6.0
# 3           NaN    NaN          NaN            NaN     NaN      NaN    NaN
# 4           NaN    NaN          NaN            NaN     NaN      NaN    NaN
#
#    涨价或折扣(元)  实付款(元)    订单状态  ... 代理商联系方式 是否代发订单 代发服务商id 微商订单号 下单批次号  下游渠道  \
# 0       0.0    85.0  等待买家付款  ...     NaN    NaN     NaN   NaN   NaN   NaN
# 1       NaN     NaN     NaN  ...     NaN    NaN     NaN   NaN   NaN   NaN
# 2       0.0    75.0  等待买家付款  ...     NaN    NaN     NaN   NaN   NaN   NaN
# 3       NaN     NaN     NaN  ...     NaN    NaN     NaN   NaN   NaN   NaN
# 4       NaN     NaN     NaN  ...     NaN    NaN     NaN   NaN   NaN   NaN
#
#    下游订单号  下单公司主体       发起人登录名  是否发起免密支付(1:淘货源诚e赊免密支付2:批量下单免密支付)
# 0    NaN     NaN  tb582836650                               NaN
# 1    NaN     NaN          NaN                               NaN
# 2    NaN     NaN  tb582836650                               NaN
# 3    NaN     NaN          NaN                               NaN
# 4    NaN     NaN          NaN                               NaN
#
# [5 rows x 49 columns]

# %%
df.shape
# Out:
# (108, 49)

# %%
df.dtypes
# Out:
# 订单编号                                       float64
# 买家公司名                                      float64
# 买家会员名                                       object
# 卖家公司名                                       object
# 卖家会员名                                       object
# 货品总价(元)                                    float64
# 运费(元)                                      float64
# 涨价或折扣(元)                                   float64
# 实付款(元)                                     float64
# 订单状态                                        object
# 订单创建时间                              datetime64[ns]
# 订单付款时间                              datetime64[ns]
# 发货方                                         object
# 收货人姓名                                       object
# 收货地址                                        object
# 邮编                                         float64
# 联系电话                                       float64
# 联系手机                                       float64
# 货品标题                                        object
# 单价(元)                                      float64
# 数量                                           int64
# 单位                                          object
# 货号                                          object
# 型号                                          object
# Offer ID                                     int64
# SKU ID                                       int64
# 物料编号                                       float64
# 单品货号                                        object
# 货品种类                                       float64
# 买家留言                                        object
# 物流公司                                        object
# 运单号                                         object
# 发票：购货单位名称                                  float64
# 发票：纳税人识别号                                  float64
# 发票：地址、电话                                   float64
# 发票：开户行及账号                                  float64
# 发票收取地址                                     float64
# 关联编号                                       float64
# 代理商姓名                                      float64
# 代理商联系方式                                    float64
# 是否代发订单                                     float64
# 代发服务商id                                    float64
# 微商订单号                                      float64
# 下单批次号                                      float64
# 下游渠道                                       float64
# 下游订单号                                      float64
# 下单公司主体                                     float64
# 发起人登录名                                      object
# 是否发起免密支付(1:淘货源诚e赊免密支付2:批量下单免密支付)           float64
# dtype: object

# %%
df.columns
# Out:
# Index(['订单编号', '买家公司名', '买家会员名', '卖家公司名', '卖家会员名', '货品总价(元)', '运费(元)',
#        '涨价或折扣(元)', '实付款(元)', '订单状态', '订单创建时间', '订单付款时间', '发货方', '收货人姓名',
#        '收货地址', '邮编', '联系电话', '联系手机', '货品标题', '单价(元)', '数量', '单位', '货号', '型号',
#        'Offer ID', 'SKU ID', '物料编号', '单品货号', '货品种类', '买家留言', '物流公司', '运单号',
#        '发票：购货单位名称', '发票：纳税人识别号', '发票：地址、电话', '发票：开户行及账号', '发票收取地址', '关联编号',
#        '代理商姓名', '代理商联系方式', '是否代发订单', '代发服务商id', '微商订单号', '下单批次号', '下游渠道',
#        '下游订单号', '下单公司主体', '发起人登录名', '是否发起免密支付(1:淘货源诚e赊免密支付2:批量下单免密支付)'],
#       dtype='object')

# %%
translated_cols = GoogleTranslator(source='auto', target='en').translate_batch(list(df.columns))
translated_cols
# Out:
# ['order number',
#  'Buyer company name',
#  'Buyer member name',
#  'Seller company name',
#  'Seller member name',
#  'Total price of goods (yuan)',
#  'Shipping fee (yuan)',
#  'Price increase or discount (yuan)',
#  'Actual payment (yuan)',
#  'Order Status',
#  'Order creation time',
#  'Order payment time',
#  'shipper',
#  'Consignee name',
#  'Shipping address',
#  'post code',
#  'contact number',
#  'Contact mobile phone',
#  'Item title',
#  'Unit price (yuan)',
#  'quantity',
#  'unit',
#  'Item number',
#  'model',
#  'Offer ID',
#  'SKU ID',
#  'Material number',
#  'Item number',
#  'Goods type',
#  "Buyer's message",
#  'Logistics company',
#  'Waybill number',
#  'Invoice: Name of purchasing unit',
#  'Invoice: Taxpayer Identification Number',
#  'Invoice: address, phone number',
#  'Invoice: Opening bank and account number',
#  'Invoice collection address',
#  'associated number',
#  'Agent name',
#  'Agent contact information',
#  'Whether to ship orders on behalf of others',
#  'Shipping service provider ID',
#  'Wechat business order number',
#  'Order batch number',
#  'Downstream channels',
#  'Downstream order number',
#  'Order placing company entity',
#  'Sponsor login name',
#  'Whether to initiate password-free payment (1: Taohuoyuancheng e-credit password-free payment 2: Batch order payment without password)']

# %%
def translate_text(text, target_lang_abbr):
  translated = GoogleTranslator(source='auto', target=target_lang_abbr).translate(text)
  return translated

# %%
start = time.time()

# %%
rows = []
for index, row in df.iterrows():
  l = []
  for column_name, cell_value in row.items():
    if(type(cell_value) == str):
      translated_cell = translate_text(cell_value, "en")
      # translated_cell = GoogleTranslator(source='auto', target='en').translate(cell_value)
      l.append(translated_cell)
    else:
      l.append(cell_value)
  rows.append(l)

# %%
end = time.time()

# %%
print(rows[0])
# Out:
# [3.704877109186608e+18, nan, 'tb582836650', 'Taizhou Luqiao Leti E-Commerce Firm', 'Loti Trading', 75.0, 10.0, 0.0, 85.0, 'Waiting for buyers payment', Timestamp('2023-12-25 18:25:35'), NaT, 'Merchant ships', 'BGL shipping warehouse by sea', '7-2 Guangxiong Middle East Warehouse, Benli Logistics Park, No. 16 Taihezhuang 1st Street, Dali Village, Baiyun District, Taihe Town, Guangzhou City, Guangdong Province DU12817+STDXB Consolidate Talk to the lady Atali Before shipment BY SEA BGL - Guangzhou.', 0.0, nan, 18922721829.0, "2023 Retro Pattern Women's Shoulder Handbag Fashionable Shoulder Large Capacity Bag Color: Off-White", 25.0, 1, 'indivual', '6019, single package weight 0.45KG', nan, 708154429646, 5146867131106, nan, '6019', 2.0, 'Please indicate on the outer packaging, DUB 12817 +STDXB BY SEA, Consolidate Talk to the lady Atali before shipping', nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, 'tb582836650', nan]

# %%
print(f"Time taken for translation {start - end} sec")
# Out:
# Time taken for translation 287.68258571624756 sec

# %%
translated_df = pd.DataFrame(rows, columns=translated_cols)

# %%
translated_df.head()
# Out:
#    order number  Buyer company name Buyer member name  \
# 0  3.704877e+18                 NaN       tb582836650
# 1           NaN                 NaN               NaN
# 2  3.704473e+18                 NaN       tb582836650
# 3           NaN                 NaN               NaN
# 4           NaN                 NaN               NaN
#
#                                  Seller company name  \
# 0                Taizhou Luqiao Leti E-Commerce Firm
# 1                                                NaN
# 2  Shenzhen Longhua District Yonghao Leather Factory
# 3                                                NaN
# 4                                                NaN
#
#            Seller member name  Total price of goods (yuan)  \
# 0                Loti Trading                         75.0
# 1                         NaN                          NaN
# 2  Xinyonghao Leather Factory                         78.0
# 3                         NaN                          NaN
# 4                         NaN                          NaN
#
#    Shipping fee (yuan)  Price increase or discount (yuan)  \
# 0                 10.0                                0.0
# 1                  NaN                                NaN
# 2                  6.0                                0.0
# 3                  NaN                                NaN
# 4                  NaN                                NaN
#
#    Actual payment (yuan)                Order Status  ...  \
# 0                   85.0  Waiting for buyers payment  ...
# 1                    NaN                         NaN  ...
# 2                   75.0  Waiting for buyers payment  ...
# 3                    NaN                         NaN  ...
# 4                    NaN                         NaN  ...
#
#   Agent contact information Whether to ship orders on behalf of others  \
# 0                       NaN                                        NaN
# 1                       NaN                                        NaN
# 2                       NaN                                        NaN
# 3                       NaN                                        NaN
# 4                       NaN                                        NaN
#
#   Shipping service provider ID Wechat business order number  \
# 0                          NaN                          NaN
# 1                          NaN                          NaN
# 2                          NaN                          NaN
# 3                          NaN                          NaN
# 4                          NaN                          NaN
#
#   Order batch number  Downstream channels  Downstream order number  \
# 0                NaN                  NaN                      NaN
# 1                NaN                  NaN                      NaN
# 2                NaN                  NaN                      NaN
# 3                NaN                  NaN                      NaN
# 4                NaN                  NaN                      NaN
#
#    Order placing company entity Sponsor login name  \
# 0                           NaN        tb582836650
# 1                           NaN                NaN
# 2                           NaN        tb582836650
# 3                           NaN                NaN
# 4                           NaN                NaN
#
#    Whether to initiate password-free payment (1: Taohuoyuancheng e-credit password-free payment 2: Batch order payment without password)
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
# [5 rows x 49 columns]

# %%
translated_df.to_excel("Order_Export_Translated.xlsx")
